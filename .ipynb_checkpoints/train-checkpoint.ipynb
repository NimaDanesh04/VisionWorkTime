# %%
import cv2 as cv
import matplotlib.pyplot as plt
import os
from uuid import uuid4
import pandas as pd
import numpy as np
import random
import tensorflow as tf
from tensorflow import keras
from keras import layersfrom sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from keras import models

# %%
'''cap = cv.VideoCapture('Video_2025-06-13_060505.wmv')
count = 0
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        print("End of video stream or error reading frame.")
        break

    # Process the 'frame' here (e.g., display, apply filters, analysis)
    #cv.imshow('Video Frame', frame)

    # Exit condition: Press 'q' to quit
    img = frame[300:600,200:800]
    cv.imwrite(os.path.join('images', f"{count}.jpg"), img)
    count += 1
    if cv.waitKey(25) & 0xFF == ord('q'):
        break
    if count % 100 == 0:
        print(count)'''
# Out:
# 'cap = cv.VideoCapture(\'Video_2025-06-13_060505.wmv\')\ncount = 0\nwhile cap.isOpened():\n    ret, frame = cap.read()\n    if not ret:\n        print("End of video stream or error reading frame.")\n        break\n\n    # Process the \'frame\' here (e.g., display, apply filters, analysis)\n    #cv.imshow(\'Video Frame\', frame)\n\n    # Exit condition: Press \'q\' to quit\n    img = frame[300:600,200:800]\n    cv.imwrite(os.path.join(\'images\', f"{count}.jpg"), img)\n    count += 1\n    if cv.waitKey(25) & 0xFF == ord(\'q\'):\n        break\n    if count % 100 == 0:\n        print(count)'

# %%
plt.imshow(frame)

# %%
plt.imshow(frame[300:600,200:800])

# %%
start_point = (200, 300)  # Top-left corner (x, y)
end_point = (800, 600)   # Bottom-right corner (x, y)
color = (0, 255, 0)      # Green color (BGR format)
thickness = 3          # Line thickness in pixels

# Draw the rectangle on the image
image_with_rectangle = cv.rectangle(frame, start_point, end_point, color, thickness)

# %%
plt.imshow(image_with_rectangle)

# %%
l_1 = [0 for i in range(61)]
l_2 = [1 for i in range(61, 200)]
l_3 = [0 for i in range(200, 293)]
l_4 = [1 for i in range(293, 1191)]
l_5 = [0 for i in range(1191, 1222)]
l_6 = [1 for i in range(1222, 1500)]
array_1 = np.array(l_1)
array_2 = np.array(l_2)
array_3 = np.array(l_3)
array_4 = np.array(l_4)
array_5 = np.array(l_5)
array_6 = np.array(l_6)

# %%
fainal_array = np.concatenate((array_1, array_2, array_3, array_4, array_5, array_6))
fainal_array.shape
# Out:
# (1500,)

# %%
df = pd.DataFrame(fainal_array)

# %%
df
# Out:
#       0
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0
# ...  ..
# 1495  1
# 1496  1
# 1497  1
# 1498  1
# 1499  1
#
# [1500 rows x 1 columns]

# %%
images = np.zeros((1500, 128, 128))
for i in range(fainal_array.shape[0]):
    img = cv.imread(os.path.join('images', f"{i}.jpg"), cv.IMREAD_GRAYSCALE)
    img = cv.resize(img, (128, 128)) / 255
    images[i] = img
    if i % 100 == 0:
        print(i)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400

# %%
fig, ax = plt.subplots(4, 4, figsize=(12, 12))
for i in range(4):
    for j in range(4):
        number = random.randint(0, 1499)
        img = images[number]
        label = fainal_array[number]
        ax[i, j].imshow(img, cmap='gray')
        ax[i, j].set_title(label)
        ax[i, j].axis('off')

# %%
x_train, x_test, y_train, y_test = train_test_split(images, df, test_size=(0.1))

# %%
input_shape = (128, 128, 1)
input_img = tf.keras.Input(shape=input_shape)

x = layers.Conv2D(16, (3, 3), activation='relu', padding='same')(input_img)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.MaxPooling2D((2, 2), padding='same')(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
encoded = layers.MaxPooling2D((2, 2), padding='same')(x)



x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(encoded)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(8, (3, 3), activation='relu', padding='same')(x)
x = layers.UpSampling2D((2, 2))(x)
x = layers.Conv2D(16, (3, 3), activation='relu')(x)
x = layers.UpSampling2D((2, 2))(x)
decoded = layers.Conv2D(1, (3, 3), activation='sigmoid', padding='same')(x)


autoencoder = tf.keras.Model(input_img, decoded, name='autoencoder')
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.summary()
# Out:
# Model: "autoencoder"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 128, 128, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 128, 128, 16)   │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 64, 64, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 64, 64, 8)      │         1,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 32, 32, 8)      │             0 │
# ...

# %%
hist = autoencoder.fit(x_train, x_train, epochs=10)

# %%
encoder = keras.Model(input_img, encoded)

# %%
encoder.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 128, 128, 1)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_14 (Conv2D)              │ (None, 128, 128, 16)   │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 64, 64, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_15 (Conv2D)              │ (None, 64, 64, 8)      │         1,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 32, 32, 8)      │             0 │
# ...

# %%
pred_train = encoder.predict(x_train)
pred_test = encoder.predict(x_test)

# %%
print(pred_train.shape)
print(pred_test.shape)

# %%
train = pred_train.reshape((3221, -1))
test = pred_test.reshape(569, -1)
train.shape

# %%
model_2 = SVC()
model_2.fit(train, y_train)

# %%
pred_2 = model_2.predict(test)
print(classification_report(pred_2, y_test))
